# %% [markdown]
# ## Tut3 - RNN recognizing MNIST numbers
#
# Based on: https://github.com/aymericdamien/TensorFlow-Examples/blob/master/notebooks/3_NeuralNetworks/recurrent_network.ipynb
#
# A Reccurent Neural Network (LSTM) implementation example using TensorFlow library.
# This example is using the MNIST database of handwritten digits (http://yann.lecun.com/exdb/mnist/)
# Long Short Term Memory paper: http://deeplearning.cs.cmu.edu/pdfs/Hochreiter97_lstm.pdf
#
# For an alternative similar implementation, see https://github.com/nlintz/TensorFlow-Tutorials/blob/master/07_lstm.py

# %%
import os
import numpy as np
import tensorflow as tf
#from tensorflow.python.ops import rnn, rnn_cell

HOME = os.environ['HOME']
dpath = HOME + "/data/tf_tut/mnist/MNIST_data"

# Import MINST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets(dpath, one_hot=True)
# Out:
# Extracting /Users/maximn/data/tf_tut/mnist/MNIST_data/train-images-idx3-ubyte.gz
# Extracting /Users/maximn/data/tf_tut/mnist/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting /Users/maximn/data/tf_tut/mnist/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting /Users/maximn/data/tf_tut/mnist/MNIST_data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# To classify images using a reccurent neural network, we consider every image
# row as a sequence of pixels. Because MNIST image shape is 28*28px, we will then
# handle 28 sequences of 28 steps for every sample.
#
# **==> 28 seqs of 28 steps for every sample**

# %%
# Parameters
learning_rate = 0.001
training_iters = 100000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 28 # MNIST data input (img shape: 28*28)
n_steps = 28 # timesteps
n_hidden = 128 # hidden layer num of features
n_classes = 10 # MNIST total classes (0-9 digits)

# tf Graph input
x = tf.placeholder("float", [None, n_steps, n_input])
y = tf.placeholder("float", [None, n_classes])

# Define weights
weights = {
    'out': tf.Variable(tf.random_normal([n_hidden, n_classes]))
}
biases = {
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# %% [markdown]
# ### The Model

# %%
def RNN(x, weights, biases):

    # Prepare data shape to match `rnn` function requirements
    # Current data input shape: (batch_size, n_steps, n_input)
    # Required shape: 'n_steps' tensors list of shape (batch_size, n_input)
    
    # Permuting batch_size and n_steps
    x = tf.transpose(x, [1, 0, 2])
    # Reshaping to (n_steps*batch_size, n_input)
    x = tf.reshape(x, [-1, n_input])
    # Split to get a list of 'n_steps' tensors of shape (batch_size, n_input)
    x = tf.split(0, n_steps, x)

    # Define a lstm cell with tensorflow
#    lstm_cell = tf.nn.rnn_cell.BasicLSTMCell(n_hidden, forget_bias=1.0, state_is_tuple=True)
    lstm_cell = tf.nn.rnn_cell.GRUCell(n_hidden)

    # Get lstm cell output
    outputs, states = tf.nn.rnn(lstm_cell, x, dtype=tf.float32)

    # Linear activation, using rnn inner loop last output
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

pred = RNN(x, weights, biases)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(pred, y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.initialize_all_variables()

# %% [markdown]
# ### Training and Evaluating the Net

# %% [markdown]
# #### Result with GRU Cells

# %%
# %%time
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Reshape data to get 28 seq of 28 elements
        batch_x = batch_x.reshape((batch_size, n_steps, n_input))
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y})
        if step % display_step == 0:
            # Calculate batch accuracy
            acc = sess.run(accuracy, feed_dict={x: batch_x, y: batch_y})
            # Calculate batch loss
            loss = sess.run(cost, feed_dict={x: batch_x, y: batch_y})
            print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + 
                  "{:.6f}".format(loss) + ", Training Accuracy= " + 
                  "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")

    # Calculate accuracy for 128 mnist test images
    test_len = 128
    test_data = mnist.test.images[:test_len].reshape((-1, n_steps, n_input))
    test_label = mnist.test.labels[:test_len]
    print("Testing Accuracy:", sess.run(accuracy, feed_dict={x: test_data, y: test_label}))
# Out:
# Iter 1280, Minibatch Loss= 1.948195, Training Accuracy= 0.28125
# Iter 2560, Minibatch Loss= 1.665990, Training Accuracy= 0.44531
# Iter 3840, Minibatch Loss= 1.316161, Training Accuracy= 0.59375
# Iter 5120, Minibatch Loss= 1.130145, Training Accuracy= 0.60156
# Iter 6400, Minibatch Loss= 0.917219, Training Accuracy= 0.69531
# Iter 7680, Minibatch Loss= 0.925471, Training Accuracy= 0.70312
# Iter 8960, Minibatch Loss= 0.764358, Training Accuracy= 0.73438
# Iter 10240, Minibatch Loss= 0.627738, Training Accuracy= 0.78125
# Iter 11520, Minibatch Loss= 0.522808, Training Accuracy= 0.82812
# Iter 12800, Minibatch Loss= 0.587044, Training Accuracy= 0.79688
# Iter 14080, Minibatch Loss= 0.457473, Training Accuracy= 0.85938
# Iter 15360, Minibatch Loss= 0.504247, Training Accuracy= 0.83594
# Iter 16640, Minibatch Loss= 0.381519, Training Accuracy= 0.90625
# Iter 17920, Minibatch Loss= 0.278599, Training Accuracy= 0.92969
# Iter 19200, Minibatch Loss= 0.335172, Training Accuracy= 0.89062
# Iter 20480, Minibatch Loss= 0.377873, Training Accuracy= 0.89844
# Iter 21760, Minibatch Loss= 0.260147, Training Accuracy= 0.93750
# Iter 23040, Minibatch Loss= 0.240682, Training Accuracy= 0.92969
# Iter 24320, Minibatch Loss= 0.393230, Training Accuracy= 0.89844
# Iter 25600, Minibatch Loss= 0.284358, Training Accuracy= 0.89062
# Iter 26880, Minibatch Loss= 0.257670, Training Accuracy= 0.91406
# Iter 28160, Minibatch Loss= 0.200049, Training Accuracy= 0.95312
# Iter 29440, Minibatch Loss= 0.182431, Training Accuracy= 0.95312
# Iter 30720, Minibatch Loss= 0.149456, Training Accuracy= 0.93750
# Iter 32000, Minibatch Loss= 0.338444, Training Accuracy= 0.89062
# Iter 33280, Minibatch Loss= 0.219095, Training Accuracy= 0.92969
# Iter 34560, Minibatch Loss= 0.092073, Training Accuracy= 0.98438
# Iter 35840, Minibatch Loss= 0.181294, Training Accuracy= 0.94531
# Iter 37120, Minibatch Loss= 0.094734, Training Accuracy= 0.96094
# Iter 38400, Minibatch Loss= 0.194201, Training Accuracy= 0.94531
# Iter 39680, Minibatch Loss= 0.087908, Training Accuracy= 0.97656
# Iter 40960, Minibatch Loss= 0.199965, Training Accuracy= 0.92969
# Iter 42240, Minibatch Loss= 0.124597, Training Accuracy= 0.96875
# Iter 43520, Minibatch Loss= 0.249774, Training Accuracy= 0.92188
# Iter 44800, Minibatch Loss= 0.132471, Training Accuracy= 0.96094
# Iter 46080, Minibatch Loss= 0.201849, Training Accuracy= 0.95312
# Iter 47360, Minibatch Loss= 0.125634, Training Accuracy= 0.96094
# Iter 48640, Minibatch Loss= 0.194868, Training Accuracy= 0.95312
# Iter 49920, Minibatch Loss= 0.134421, Training Accuracy= 0.96875
# Iter 51200, Minibatch Loss= 0.111653, Training Accuracy= 0.96094
# Iter 52480, Minibatch Loss= 0.109159, Training Accuracy= 0.96875
# Iter 53760, Minibatch Loss= 0.131872, Training Accuracy= 0.95312
# Iter 55040, Minibatch Loss= 0.350207, Training Accuracy= 0.92969
# Iter 56320, Minibatch Loss= 0.105349, Training Accuracy= 0.96875
# Iter 57600, Minibatch Loss= 0.164138, Training Accuracy= 0.94531
# Iter 58880, Minibatch Loss= 0.198369, Training Accuracy= 0.92969
# Iter 60160, Minibatch Loss= 0.071174, Training Accuracy= 0.98438
# Iter 61440, Minibatch Loss= 0.185013, Training Accuracy= 0.92969
# Iter 62720, Minibatch Loss= 0.087602, Training Accuracy= 0.96094
# Iter 64000, Minibatch Loss= 0.118549, Training Accuracy= 0.95312
# Iter 65280, Minibatch Loss= 0.162504, Training Accuracy= 0.94531
# Iter 66560, Minibatch Loss= 0.160034, Training Accuracy= 0.95312
# Iter 67840, Minibatch Loss= 0.170889, Training Accuracy= 0.94531
# Iter 69120, Minibatch Loss= 0.105869, Training Accuracy= 0.96875
# Iter 70400, Minibatch Loss= 0.112421, Training Accuracy= 0.96875
# Iter 71680, Minibatch Loss= 0.133476, Training Accuracy= 0.93750
# Iter 72960, Minibatch Loss= 0.070065, Training Accuracy= 0.96875
# Iter 74240, Minibatch Loss= 0.144054, Training Accuracy= 0.96875
# Iter 75520, Minibatch Loss= 0.108905, Training Accuracy= 0.96875
# Iter 76800, Minibatch Loss= 0.072084, Training Accuracy= 0.97656
# Iter 78080, Minibatch Loss= 0.114234, Training Accuracy= 0.96875
# Iter 79360, Minibatch Loss= 0.132061, Training Accuracy= 0.94531
# Iter 80640, Minibatch Loss= 0.088176, Training Accuracy= 0.96094
# Iter 81920, Minibatch Loss= 0.085114, Training Accuracy= 0.96094
# Iter 83200, Minibatch Loss= 0.058731, Training Accuracy= 0.97656
# Iter 84480, Minibatch Loss= 0.084463, Training Accuracy= 0.96875
# Iter 85760, Minibatch Loss= 0.065763, Training Accuracy= 0.97656
# Iter 87040, Minibatch Loss= 0.056676, Training Accuracy= 0.98438
# Iter 88320, Minibatch Loss= 0.060578, Training Accuracy= 0.99219
# Iter 89600, Minibatch Loss= 0.132629, Training Accuracy= 0.96875
# Iter 90880, Minibatch Loss= 0.153953, Training Accuracy= 0.95312
# Iter 92160, Minibatch Loss= 0.098711, Training Accuracy= 0.96875
# Iter 93440, Minibatch Loss= 0.124586, Training Accuracy= 0.97656
# Iter 94720, Minibatch Loss= 0.131600, Training Accuracy= 0.96875
# Iter 96000, Minibatch Loss= 0.210622, Training Accuracy= 0.93750
# Iter 97280, Minibatch Loss= 0.078860, Training Accuracy= 0.97656
# Iter 98560, Minibatch Loss= 0.054448, Training Accuracy= 0.99219
# Iter 99840, Minibatch Loss= 0.103180, Training Accuracy= 0.96875
# Optimization Finished!
# Testing Accuracy: 1.0
# CPU times: user 2min 41s, sys: 13.8 s, total: 2min 55s
# Wall time: 1min 6s

# %% [markdown]
# #### Result with LSTM Cells

# %%
# %%time
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Reshape data to get 28 seq of 28 elements
        batch_x = batch_x.reshape((batch_size, n_steps, n_input))
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y})
        if step % display_step == 0:
            # Calculate batch accuracy
            acc = sess.run(accuracy, feed_dict={x: batch_x, y: batch_y})
            # Calculate batch loss
            loss = sess.run(cost, feed_dict={x: batch_x, y: batch_y})
            print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + 
                  "{:.6f}".format(loss) + ", Training Accuracy= " + 
                  "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")

    # Calculate accuracy for 128 mnist test images
    test_len = 128
    test_data = mnist.test.images[:test_len].reshape((-1, n_steps, n_input))
    test_label = mnist.test.labels[:test_len]
    print("Testing Accuracy:", sess.run(accuracy, feed_dict={x: test_data, y: test_label}))
# Out:
# Iter 1280, Minibatch Loss= 1.897562, Training Accuracy= 0.33594
# Iter 2560, Minibatch Loss= 1.640621, Training Accuracy= 0.46094
# Iter 3840, Minibatch Loss= 1.279966, Training Accuracy= 0.57031
# Iter 5120, Minibatch Loss= 1.117690, Training Accuracy= 0.63281
# Iter 6400, Minibatch Loss= 0.902289, Training Accuracy= 0.70312
# Iter 7680, Minibatch Loss= 0.635122, Training Accuracy= 0.78906
# Iter 8960, Minibatch Loss= 0.671882, Training Accuracy= 0.75781
# Iter 10240, Minibatch Loss= 0.617051, Training Accuracy= 0.82031
# Iter 11520, Minibatch Loss= 0.418730, Training Accuracy= 0.88281
# Iter 12800, Minibatch Loss= 0.376057, Training Accuracy= 0.88281
# Iter 14080, Minibatch Loss= 0.315794, Training Accuracy= 0.87500
# Iter 15360, Minibatch Loss= 0.400999, Training Accuracy= 0.85156
# Iter 16640, Minibatch Loss= 0.436320, Training Accuracy= 0.87500
# Iter 17920, Minibatch Loss= 0.343609, Training Accuracy= 0.90625
# Iter 19200, Minibatch Loss= 0.289465, Training Accuracy= 0.89844
# Iter 20480, Minibatch Loss= 0.285290, Training Accuracy= 0.89844
# Iter 21760, Minibatch Loss= 0.123415, Training Accuracy= 0.95312
# Iter 23040, Minibatch Loss= 0.355999, Training Accuracy= 0.91406
# Iter 24320, Minibatch Loss= 0.211309, Training Accuracy= 0.94531
# Iter 25600, Minibatch Loss= 0.306805, Training Accuracy= 0.92188
# Iter 26880, Minibatch Loss= 0.195844, Training Accuracy= 0.93750
# Iter 28160, Minibatch Loss= 0.209449, Training Accuracy= 0.91406
# Iter 29440, Minibatch Loss= 0.322677, Training Accuracy= 0.92969
# Iter 30720, Minibatch Loss= 0.258318, Training Accuracy= 0.92969
# Iter 32000, Minibatch Loss= 0.141536, Training Accuracy= 0.96875
# Iter 33280, Minibatch Loss= 0.214892, Training Accuracy= 0.93750
# Iter 34560, Minibatch Loss= 0.201980, Training Accuracy= 0.93750
# Iter 35840, Minibatch Loss= 0.182470, Training Accuracy= 0.96875
# Iter 37120, Minibatch Loss= 0.118417, Training Accuracy= 0.96094
# Iter 38400, Minibatch Loss= 0.150614, Training Accuracy= 0.97656
# Iter 39680, Minibatch Loss= 0.176228, Training Accuracy= 0.93750
# Iter 40960, Minibatch Loss= 0.177011, Training Accuracy= 0.95312
# Iter 42240, Minibatch Loss= 0.131639, Training Accuracy= 0.96094
# Iter 43520, Minibatch Loss= 0.287179, Training Accuracy= 0.91406
# Iter 44800, Minibatch Loss= 0.101724, Training Accuracy= 0.97656
# Iter 46080, Minibatch Loss= 0.104484, Training Accuracy= 0.96094
# Iter 47360, Minibatch Loss= 0.262459, Training Accuracy= 0.89062
# Iter 48640, Minibatch Loss= 0.219004, Training Accuracy= 0.93750
# Iter 49920, Minibatch Loss= 0.123989, Training Accuracy= 0.96094
# Iter 51200, Minibatch Loss= 0.098006, Training Accuracy= 0.95312
# Iter 52480, Minibatch Loss= 0.164647, Training Accuracy= 0.96094
# Iter 53760, Minibatch Loss= 0.141628, Training Accuracy= 0.95312
# Iter 55040, Minibatch Loss= 0.200487, Training Accuracy= 0.93750
# Iter 56320, Minibatch Loss= 0.171759, Training Accuracy= 0.92188
# Iter 57600, Minibatch Loss= 0.109490, Training Accuracy= 0.96875
# Iter 58880, Minibatch Loss= 0.190124, Training Accuracy= 0.93750
# Iter 60160, Minibatch Loss= 0.276894, Training Accuracy= 0.96094
# Iter 61440, Minibatch Loss= 0.170237, Training Accuracy= 0.92188
# Iter 62720, Minibatch Loss= 0.117689, Training Accuracy= 0.96094
# Iter 64000, Minibatch Loss= 0.263408, Training Accuracy= 0.93750
# Iter 65280, Minibatch Loss= 0.092377, Training Accuracy= 0.96094
# Iter 66560, Minibatch Loss= 0.052333, Training Accuracy= 0.99219
# Iter 67840, Minibatch Loss= 0.119598, Training Accuracy= 0.95312
# Iter 69120, Minibatch Loss= 0.098223, Training Accuracy= 0.97656
# Iter 70400, Minibatch Loss= 0.085393, Training Accuracy= 0.98438
# Iter 71680, Minibatch Loss= 0.069398, Training Accuracy= 0.98438
# Iter 72960, Minibatch Loss= 0.103583, Training Accuracy= 0.96094
# Iter 74240, Minibatch Loss= 0.139128, Training Accuracy= 0.95312
# Iter 75520, Minibatch Loss= 0.105848, Training Accuracy= 0.97656
# Iter 76800, Minibatch Loss= 0.051537, Training Accuracy= 0.98438
# Iter 78080, Minibatch Loss= 0.067337, Training Accuracy= 0.96875
# Iter 79360, Minibatch Loss= 0.059000, Training Accuracy= 0.97656
# Iter 80640, Minibatch Loss= 0.080995, Training Accuracy= 0.98438
# Iter 81920, Minibatch Loss= 0.080902, Training Accuracy= 0.97656
# Iter 83200, Minibatch Loss= 0.086081, Training Accuracy= 0.95312
# Iter 84480, Minibatch Loss= 0.128592, Training Accuracy= 0.96875
# Iter 85760, Minibatch Loss= 0.197417, Training Accuracy= 0.93750
# Iter 87040, Minibatch Loss= 0.153756, Training Accuracy= 0.95312
# Iter 88320, Minibatch Loss= 0.113069, Training Accuracy= 0.96094
# Iter 89600, Minibatch Loss= 0.062482, Training Accuracy= 0.97656
# Iter 90880, Minibatch Loss= 0.143791, Training Accuracy= 0.95312
# Iter 92160, Minibatch Loss= 0.114581, Training Accuracy= 0.96094
# Iter 93440, Minibatch Loss= 0.127223, Training Accuracy= 0.95312
# Iter 94720, Minibatch Loss= 0.068286, Training Accuracy= 0.96094
# Iter 96000, Minibatch Loss= 0.087200, Training Accuracy= 0.96875
# Iter 97280, Minibatch Loss= 0.090863, Training Accuracy= 0.97656
# Iter 98560, Minibatch Loss= 0.156020, Training Accuracy= 0.96094
# Iter 99840, Minibatch Loss= 0.072366, Training Accuracy= 0.99219
# Optimization Finished!
# Testing Accuracy: 0.960938
# CPU times: user 3min 6s, sys: 12.6 s, total: 3min 18s
# Wall time: 1min 11s
